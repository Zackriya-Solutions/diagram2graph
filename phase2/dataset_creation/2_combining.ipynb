# %%
import os
import pandas as pd

# %%
kamizuru_df = pd.read_csv('dataset_from_kamizuru/metadata.csv')
block_df = pd.read_csv('dataset_from_block/metadata.csv')

# %%
kamizuru_df
# Out:
#         file                                                c2t
# 0      1.png  Start is connected with Input which is then co...
# 1      2.png  Start is connected with Initialize which is th...
# 2      4.png  Begin is connected with Initialize weights and...
# 3      6.png  Start is connected with Is target sector < max...
# 4     11.png  START is connected with K is equal to 0 which ...
# ..       ...                                                ...
# 110  286.png  Start is connected with Interested in watching...
# 111  287.png  Start is connected with Read Temperature which...
# 112  288.png  Begin is connected with Pre-configuration whic...
# 113  292.png  Start is connected with Read which is then con...
# 114  295.png  Begin is connected with Do You Understand Flow...
#
# [115 rows x 2 columns]

# %%
block_df
# Out:
#        file                                                c2t
# 0     0.png  Start is connected with Check needs for projec...
# 1   401.png  Start is connected with Check software. If Che...
# 2   402.png  Begin is conected with Check your PC configura...
# 3     3.png  Begin is conected with SUM=0 which is then con...
# 4   406.png  Begin is connected with calculate total travel...
# ..      ...                                                ...
# 76  363.png  Strat is connected with Initialize parameters ...
# 77  375.png  Begin is connected with i=0 which is then conn...
# 78  380.png  Start is connected with Read Inputs which is t...
# 79  393.png  Start is connected with Requirements which is ...
# 80  394.png  Start is connected with Power On which is then...
#
# [81 rows x 2 columns]

# %%
for i, row in block_df.iterrows():
    if row['file'] in kamizuru_df['file'].values:
        print(row['file'])
